# %% [markdown]
# ## EDA of Delaware Vets
# @xt0fer Kris Younger
#
# looking at a dataset from https://catalog.data.gov/dataset/gravesite-locations-of-veterans-and-beneficiaries-in-delaware-as-of-may-2019

# %%
import pandas as pd
import numpy as np

# %%
full_set = pd.read_csv("ngl_delaware.csv",header=None,sep='\t')

# %%
full_set.head()
# Out:
#         d_first_name d_mid_name d_last_name    d_suffix d_birth_date  \
# Jesse              L   Williams          Jr  05/23/1964   02/25/2018
# Lila               M   Childres         NaN  08/25/1931   02/26/2018
# Gregory            L      Young         NaN  12/06/1948   10/26/2017
# Paul               B  Littleton         NaN  08/18/1929   10/21/2017
# Allan              D   Stephens         NaN  04/23/1945   10/24/2017
#
#         d_death_date section_id  row_num  \
# Jesse              G          I     10.0
# Lila               C          O      5.0
# Gregory            G          G     10.0
# Paul               H          M      7.0
# Allan              G          G     11.0
#
#                                                site_num            cem_name  \
# Jesse    DELAWARE VETERANS MEMORIAL CEMETERY-SUSSEX CO.  26669 Patriots Way
# Lila     DELAWARE VETERANS MEMORIAL CEMETERY-SUSSEX CO.  26669 Patriots Way
# ...

# %%
full_set.tail()
# Out:
#          d_first_name  d_mid_name d_last_name    d_suffix d_birth_date  \
# Carl                R  Cartwright         NaN  11/30/1947   10/20/1991
# Nancy               A       Mento         NaN  06/18/1946   06/26/1998
# Nicholas          NaN  Drahuschak         NaN  12/20/1928   12/28/1991
# James               F       Leruo         NaN  02/19/1936   03/29/2003
# Joseph              J    Pecoraro         NaN  05/06/1923   03/18/2012
#
#          d_death_date section_id  row_num  \
# Carl                B          M     12.0
# Nancy              XI          B      9.0
# Nicholas            B          L     15.0
# James              2D          P     16.0
# Joseph              G          H      7.0
#
#                                                 site_num  \
# Carl                 DELAWARE VETERANS MEMORIAL CEMETERY
# Nancy                DELAWARE VETERANS MEMORIAL CEMETERY
# Nicholas             DELAWARE VETERANS MEMORIAL CEMETERY
# ...
